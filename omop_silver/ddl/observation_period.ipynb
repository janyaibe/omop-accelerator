# %%
# %sql
CREATE TABLE IF NOT EXISTS _exponent.omop_silver.observation_period (
  -- observation_period_id BIGINT NOT NULL COMMENT 'PK (OMOP: integer) - generated in mapping table',
  observation_period_start_date DATE NOT NULL COMMENT 'Start date of observation period (OMOP: date)',
  observation_period_end_date DATE NOT NULL COMMENT 'End date of observation period (OMOP: date)',
  period_type_concept_id INT NOT NULL COMMENT 'FK -> concept.concept_id (Period type) (OMOP: integer)',
  person_source_value STRING NOT NULL COMMENT 'Source person identifier for FK lookup (ex: allscripts_tw | 12345)',
  observation_period_source_value STRING NOT NULL COMMENT 'Unique source identifier for this observation period',
  source_system STRING COMMENT 'Source system (ex: allscripts_tw)',
  last_mod_tsp TIMESTAMP COMMENT 'Timestamp of last modification'
)
USING DELTA
COMMENT 'OMOP CDM v5.4 SILVER OBSERVATION_PERIOD table - staging for gold layer';
