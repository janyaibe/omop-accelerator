# %%
# %sql
CREATE TABLE IF NOT EXISTS _exponent.omop.concept_ancestor (
  ancestor_concept_id INT NOT NULL COMMENT 'FK -> concept.concept_id (OMOP: integer)',
  descendant_concept_id INT NOT NULL COMMENT 'FK -> concept.concept_id (OMOP: integer)',
  min_levels_of_separation INT NOT NULL COMMENT 'Min separation (OMOP: integer)',
  max_levels_of_separation INT NOT NULL COMMENT 'Max separation (OMOP: integer)'
)
USING DELTA
COMMENT 'OMOP CDM v5.4 CONCEPT_ANCESTOR table';
