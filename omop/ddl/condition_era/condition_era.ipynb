# %%
# %sql
CREATE OR REPLACE TABLE _exponent.omop.condition_era (
  condition_era_id BIGINT NOT NULL GENERATED BY DEFAULT AS IDENTITY (START WITH 1 INCREMENT BY 1) COMMENT 'PK (OMOP: integer)',
  person_id BIGINT NOT NULL COMMENT 'FK -> person.person_id (OMOP: integer)',
  condition_concept_id INT NOT NULL COMMENT 'FK -> concept.concept_id (Condition) (OMOP: integer)',
  condition_era_start_date DATE NOT NULL COMMENT 'Start date (OMOP: date)',
  condition_era_end_date DATE NOT NULL COMMENT 'End date (OMOP: date)',
  condition_occurrence_count INT COMMENT 'Count of contributing condition_occurrence rows (OMOP: integer)'
)
USING DELTA
COMMENT 'OMOP CDM v5.4 CONDITION_ERA table';
