# %%
# %sql
CREATE OR REPLACE TABLE _exponent.omop.episode_event (
  episode_event_id BIGINT GENERATED BY DEFAULT AS IDENTITY NOT NULL COMMENT 'PK (OMOP: integer)',
  episode_id BIGINT NOT NULL COMMENT 'FK -> episode.episode_id (OMOP: integer)',
  event_id BIGINT NOT NULL COMMENT 'ID of event row in its domain table (OMOP: integer)',
  episode_event_field_concept_id INT NOT NULL COMMENT 'FK -> concept (field identifies domain)',
  episode_event_concept_id INT COMMENT 'FK -> concept (optional)'
)
USING DELTA
COMMENT 'OMOP CDM v5.4 EPISODE_EVENT table';
