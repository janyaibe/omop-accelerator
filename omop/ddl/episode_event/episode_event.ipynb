# %%
# %sql
CREATE OR REPLACE TABLE _exponent.omop.episode_event (
  episode_id BIGINT NOT NULL COMMENT 'FK -> episode.episode_id (OMOP: integer)',
  event_id BIGINT GENERATED ALWAYS AS IDENTITY COMMENT 'ID of event in its table (OMOP: integer)',
  episode_event_field_concept_id INT NOT NULL COMMENT 'FK -> concept.concept_id (Field concept identifying event table) (OMOP: integer)',
  episode_event_concept_id INT COMMENT 'FK -> concept.concept_id (Event concept, optional) (OMOP: integer)'
)
USING DELTA
COMMENT 'OMOP CDM v5.4 EPISODE_EVENT table';
